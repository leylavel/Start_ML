# %% [markdown]
# ### В данном уроке мы выделим еще несколько потенциально важных фичей из изначального датасета и попробуем применить изученные методы отбора признаков к итоговому датасету.

# %%
import numpy as np
import pandas as pd

processed_data = pd.read_csv('processed_data.csv', index_col='id')

processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  trip_duration  \
# id
# id2875421          1       930.399753                   0          455.0
# id2377394          0       930.399753                   0          663.0
# id3858529          1       930.399753                   0         2124.0
# id3504673          1       930.399753                   0          429.0
# id2181028          1       930.399753                   0          435.0
#
#            distance_km
# id
# id2875421     1.500479
# id2377394     1.807119
# id3858529     6.392080
# id3504673     1.487155
# id2181028     1.189925

# %%
processed_data['log_trip_duration'] = np.log1p(processed_data['trip_duration'])

# %%
processed_data.drop('trip_duration', axis = 1, inplace = True)

# %%
processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration
# id
# id2875421           6.122493
# id2377394           6.498282
# id3858529           7.661527
# id3504673           6.063785
# id2181028           6.077642

# %%
initial_data = pd.read_csv('taxi_dataset.csv')

initial_data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id2875421          2  2016-03-14 17:24:55  2016-03-14 17:32:30
# 1  id2377394          1  2016-06-12 00:43:35  2016-06-12 00:54:38
# 2  id3858529          2  2016-01-19 11:35:24  2016-01-19 12:10:48
# 3  id3504673          2  2016-04-06 19:32:31  2016-04-06 19:39:40
# 4  id2181028          2  2016-03-26 13:30:55  2016-03-26 13:38:10
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.982155        40.767937         -73.964630
# 1                1        -73.980415        40.738564         -73.999481
# 2                1        -73.979027        40.763939         -74.005333
# 3                1        -74.010040        40.719971         -74.012268
# 4                1        -73.973053        40.793209         -73.972923
#
#    dropoff_latitude store_and_fwd_flag
# 0         40.765602                  N
# 1         40.731152                  N
# 2         40.710087                  N
# 3         40.706718                  N
# 4         40.782520                  N

# %%
initial_data.shape[0] == processed_data.shape[0]
# Out:
# True

# %%
### Вернем в датасет колонку pickup_datetime

initial_data = initial_data.set_index('id')

processed_data = pd.merge(processed_data, initial_data['pickup_datetime'],
                          left_index=True, right_index=True)

# %%
processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration      pickup_datetime
# id
# id2875421           6.122493  2016-03-14 17:24:55
# id2377394           6.498282  2016-06-12 00:43:35
# id3858529           7.661527  2016-01-19 11:35:24
# id3504673           6.063785  2016-04-06 19:32:31
# id2181028           6.077642  2016-03-26 13:30:55

# %% [markdown]
# Напомним, **pickup_datetime** - время начала поездки.
#
# Кажется, что в зависимости от месяца/дня недели/времени суток движение на дорогах может отличаться. Как из-за погодных условий, так и из-за загруженности транспорта. Поэтому, есть подозрение, что будет полезно выделить ряд признаков из колонки **pickup_datetime**. Давайте исследуем зависимость нашей таргетной переменной от указанных факторов.

# %%
processed_data['pickup_datetime'] = pd.to_datetime(processed_data['pickup_datetime'])

processed_data['date'] = processed_data.pickup_datetime.dt.date
processed_data['day_of_week'] = processed_data.pickup_datetime.dt.dayofweek
processed_data['hour'] = processed_data.pickup_datetime.dt.hour
processed_data['month'] = processed_data.pickup_datetime.dt.month

# %%
processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration     pickup_datetime        date  day_of_week  \
# id
# id2875421           6.122493 2016-03-14 17:24:55  2016-03-14            0
# id2377394           6.498282 2016-06-12 00:43:35  2016-06-12            6
# id3858529           7.661527 2016-01-19 11:35:24  2016-01-19            1
# id3504673           6.063785 2016-04-06 19:32:31  2016-04-06            2
# id2181028           6.077642 2016-03-26 13:30:55  2016-03-26            5
#
#            hour  month
# id
# id2875421    17      3
# id2377394     0      6
# id3858529    11      1
# id3504673    19      4
# id2181028    13      3

# %% [markdown]
# Исследуем, когда и сколько поездок было совершено.
#
# Начнем с графиков, показывающих количество поездок в зависимости от времени суток/даты и т.д.
#
# Так же полезно сразу показать и среднее значение таргетной переменной.

# %%
processed_data.date.unique().shape[0]
# Out:
# 182

# %%
import matplotlib.pyplot as plt

fig = plt.figure()

fig.set_size_inches(16, 10)

ax_1 = fig.add_subplot(1, 2, 1)
plt.hist(processed_data['date'], bins=processed_data.date.unique().shape[0])#bins - количество столбцов одинак ширины по Ох
plt.ylim((4000, 10000))

ax_2 = fig.add_subplot(1, 2, 2)
plt.bar(sorted(list(processed_data['date'].unique())), 
        processed_data.groupby('date', as_index=False)['log_trip_duration'].mean()['log_trip_duration'],
        width=1)
plt.ylim((6, 7))

fig.tight_layout()#чтобы тайтлы не сливались с осями

ax_1.set(title = 'Количество поездок по датам')
ax_2.set(title = 'Средняя логарифмированная продолжительность поездок по датам')

plt.show()

# %% [markdown]
# Кажется, что внутри недели есть некоторая зависимость таргета от дня недели.
#
# Такая же зависимость может оказаться и внутри дня (в завимости от часов).
#
# Предлагаю исследовать эту зависимость подробнее.
#
# Изобразите следующие графики зависимостей:
#
# - Количество поездок/Средняя продолжительность поездки vs День недели
# - Количество поездок/Средняя продолжительность поездки vs время суток
# - Средняя продолжительность поездки vs время суток для каждого дня недели (например, нарисовав с разными цветами и, соответственно, легендами)
# - Аналогичные графики, используя информацию о месяце, внутри которого была совершена поездка.
# - Ящики с усами для различных: времени суток, дня недели, месяца
#
# Используйте любые доступные инструменты pyplot!
#
# Далее, на основе полученных результатов, мы будем принимать решение о создании новых признаков.
#
# EDA можно использовать не только для того, чтобы понять, какие фичи можно убрать из датасета. Но и для выделения базовых признаков. Этим и займемся!
#
# P.S. Сами графики мы проверять у Вас не будем. Зато для ответа на устные вопросы понадобятся, поэтому, в любом случае, крайне рекомендуем поупражняться. Поэтому рисовать все графики не обязательно - ограничьтесь теми, которые помогут Вам ответить на тестовые вопросы.
#
# **Hint**: обратите внимание на сильную просадку в январе. Почему она могла произойти - можно прочитать <a href="https://en.wikipedia.org/wiki/January_2016_United_States_blizzard"> здесь</a>. В будущем можно будет создать бинарный признак "произошла ли поездка во время сильного снегопада".

# %%
plt.bar(sorted(list(processed_data['date'].unique())), 
        processed_data.groupby('date', as_index=False)['log_trip_duration'].mean()['log_trip_duration'],
        width=1)
plt.ylim((6, 7))
# Out:
# (6.0, 7.0)

# %%
### Your code is here
fig = plt.figure()
fig.set_size_inches(10, 4)

ax_1 = fig.add_subplot(1, 2, 1)
plt.bar( sorted(list(processed_data['day_of_week'].unique())), processed_data.groupby('day_of_week', as_index=False)['log_trip_duration'].mean()['log_trip_duration'])
plt.ylim(6.3, 6.6)

ax_2 = fig.add_subplot(1, 2, 2)
plt.bar(sorted(list(processed_data['hour'].unique())), processed_data.groupby('hour', as_index=False)['log_trip_duration'].mean()['log_trip_duration'])
plt.ylim(6, 6.6)
ax_1.set(title = 'Cредний таргет по дням недели')
ax_2.set(title = 'Cредний таргет по часам')
plt.show()

# %%
day_hour = processed_data.groupby(['day_of_week', 'hour']).mean()['log_trip_duration'].reset_index()
day_hour.head()
# Out:
#    day_of_week  hour  log_trip_duration
# 0            0     0           6.328173
# 1            0     1           6.289221
# 2            0     2           6.260257
# 3            0     3           6.321038
# 4            0     4           6.325626

# %% [markdown]
# ## Pivot Table usage
# pivot_tables - сводные таблицы в пандасе. Удобно группировать данные по признакам.
# https://jakevdp.github.io/PythonDataScienceHandbook/03.09-pivot-tables.html

# %%
day_hour_pivot = day_hour.pivot(index = 'hour', columns = 'day_of_week', values = 'log_trip_duration')
display(day_hour_pivot)
# Out:
# day_of_week         0         1         2         3         4         5  \
# hour
# 0            6.328173  6.353598  6.361024  6.368642  6.433067  6.486600
# 1            6.289221  6.316450  6.290582  6.287852  6.368686  6.417126
# 2            6.260257  6.277271  6.226347  6.280400  6.297224  6.365256
# 3            6.321038  6.241751  6.256435  6.272725  6.311585  6.323040
# 4            6.325626  6.329338  6.284243  6.285450  6.369078  6.339929
# 5            6.256471  6.140184  6.122148  6.193495  6.278671  6.357487
# 6            6.184772  6.155556  6.162004  6.175040  6.198555  6.238505
# 7            6.359147  6.371453  6.388129  6.383752  6.362452  6.169255
# 8            6.498381  6.520274  6.527269  6.539392  6.500891  6.194081
# 9            6.516128  6.579237  6.564734  6.589689  6.561945  6.214604
# 10           6.512313  6.600997  6.606604  6.605446  6.570514  6.269338
# 11           6.522476  6.635141  6.644226  6.635055  6.586366  6.344829
# 12           6.502599  6.609847  6.630905  6.623803  6.572487  6.387217
# 13           6.496144  6.602237  6.640205  6.620438  6.547999  6.444176
# 14           6.503294  6.614188  6.638930  6.669526  6.602534  6.459696
# 15           6.515543  6.587715  6.647091  6.650622  6.632537  6.478536
# 16           6.473270  6.563368  6.607306  6.630965  6.600848  6.458692
# 17           6.469051  6.561009  6.615679  6.591111  6.549169  6.495177
# 18           6.440283  6.515514  6.554105  6.566069  6.513204  6.480299
# 19           6.337701  6.417506  6.459194  6.493924  6.462670  6.503001
# 20           6.336174  6.392049  6.429218  6.480190  6.452414  6.456622
# 21           6.361631  6.420383  6.457608  6.498623  6.459232  6.444083
# 22           6.371409  6.458666  6.475148  6.529495  6.512968  6.495427
# 23           6.378529  6.409343  6.449505  6.497576  6.539116  6.514911
#
# day_of_week         6
# hour
# 0            6.465794
# 1            6.423073
# 2            6.353585
# 3            6.350705
# 4            6.325216
# 5            6.341709
# 6            6.280519
# 7            6.160052
# 8            6.112782
# 9            6.147650
# 10           6.207443
# 11           6.290312
# 12           6.359007
# 13           6.426654
# 14           6.482152
# 15           6.491881
# 16           6.496014
# 17           6.480505
# 18           6.444940
# 19           6.389709
# 20           6.359214
# 21           6.341452
# 22           6.353287
# 23           6.357831

# %%
#график зависимости среднего значения протяженности поездки от часов дня(для рзаных дней недели).
day_hour_pivot.plot(figsize = (15, 8))
# Out:
# <AxesSubplot:xlabel='hour'>

# %%
#сделаем таблицу для определения корреляции между количеством поездок в день и среднего значения таргета 
df = processed_data.groupby('day_of_week').agg({'log_trip_duration':['count', 'mean']})
df = df.reset_index()
df = df.droplevel(1, axis = 1)

df_columns = ['day_of_week', 'log_trip_duration_count', 'log_trip_duration_mean']
df.set_axis(df_columns, axis = 1, inplace = True)
df['log_trip_duration_count'].corr(df['log_trip_duration_mean'])
# Out:
# 0.527163535172774

# %%
#узнаем среднее значение таргета в зависимости от месяца и дней недели в нём 
day_month = processed_data.groupby(['day_of_week', 'month']).mean()['log_trip_duration'].reset_index()
day_month.head()
# Out:
#    day_of_week  month  log_trip_duration
# 0            0      1           6.392290
# 1            0      2           6.378633
# 2            0      3           6.417520
# 3            0      4           6.445311
# 4            0      5           6.452634

# %%
day_month_pivot = day_month.pivot(index = 'month', columns = 'day_of_week', values = 'log_trip_duration')
display(day_month_pivot)
# Out:
# day_of_week         0         1         2         3         4         5  \
# month
# 1            6.392290  6.471848  6.455752  6.474975  6.434880  6.373989
# 2            6.378633  6.453226  6.464920  6.469679  6.456341  6.389116
# 3            6.417520  6.457490  6.481932  6.510414  6.483786  6.410283
# 4            6.445311  6.500645  6.516521  6.547169  6.531337  6.433370
# 5            6.452634  6.539478  6.577882  6.590721  6.553208  6.447865
# 6            6.477131  6.522432  6.577569  6.572375  6.549085  6.459058
#
# day_of_week         6
# month
# 1            6.337723
# 2            6.349146
# 3            6.365961
# 4            6.388860
# 5            6.402535
# 6            6.421463

# %%
day_month_pivot.plot(figsize = (15, 8))
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# Кажется, что полученные выводы из графиков выше достаточны для того, чтобы посчитать признаки, связанные с временем/датой поездки, достаточно важными. На их основе выделим еще пару.
#
# Добавьте следующие бинарные признаки:
#
#
# 1. Была ли в день поездки буря (основываясь на единственном обнаруженном таком дне)
# 2. Является ли время поездки статистически самым проблемным, то есть час пиком?
#
# Для создания 2ой фичи используйте следующую логику: посчитаем для каждой пары "день недели"-"время суток" среднее значение таргета. Найдем топ-10 самых "больших" пар. Если поездка была совершена во входящее в этот топ время, то ставим 1. Иначе - 0. Получается бинарный признак.
#
# P.S. назовите колонки **anomaly** и **traffic_jam**

# %%
### Создадим первый бинарный признак
### Your code is here
import datetime
processed_data['anomaly'] = 0
processed_data.loc[processed_data.date == datetime.date(2016, 1, 23), 'anomaly'] = 1

# %%
processed_data['anomaly'].value_counts()
# Out:
# 0    1456996
# 1       1648
# Name: anomaly, dtype: int64

# %%
### Создадим второй бинарный признак
### Your code is here
sec_feat = processed_data.groupby(['day_of_week', 'hour']).agg({'log_trip_duration':'mean'}).rename(columns = {'log_trip_duration':'average_log_trip_dur'})\
                                                .sort_values(by = 'average_log_trip_dur', ascending = False).reset_index().iloc[:10]
sec_feat
# Out:
#    day_of_week  hour  average_log_trip_dur
# 0            3    14              6.669526
# 1            3    15              6.650622
# 2            2    15              6.647091
# 3            2    11              6.644226
# 4            2    13              6.640205
# 5            2    14              6.638930
# 6            1    11              6.635141
# 7            3    11              6.635055
# 8            4    15              6.632537
# 9            3    16              6.630965

# %%
list(sec_feat.apply(tuple, axis = 1))
# Out:
# [(3.0, 14.0, 6.66952559761702),
#  (3.0, 15.0, 6.650621840230547),
#  (2.0, 15.0, 6.647091210740605),
#  (2.0, 11.0, 6.644226455326701),
#  (2.0, 13.0, 6.640205151991797),
#  (2.0, 14.0, 6.638930062583945),
#  (1.0, 11.0, 6.635141214679252),
#  (3.0, 11.0, 6.635055103255098),
#  (4.0, 15.0, 6.632537099864104),
#  (3.0, 16.0, 6.630965086169385)]

# %%
processed_data['traffic_jam'] = 0

# %%
for x in list(sec_feat.apply(tuple, axis = 1)):
    print(x[0], x[1])
# Out:
# 3.0 14.0
# 3.0 15.0
# 2.0 15.0
# 2.0 11.0
# 2.0 13.0
# 2.0 14.0
# 1.0 11.0
# 3.0 11.0
# 4.0 15.0
# 3.0 16.0

# %%
for x in list(sec_feat.apply(tuple, axis = 1)):
    processed_data.loc[(processed_data['day_of_week'] == x[0]) & (processed_data['hour'] == x[1]), 'traffic_jam'] = 1

# %%
processed_data['traffic_jam'].value_counts()
# Out:
# 0    1357860
# 1     100784
# Name: traffic_jam, dtype: int64

# %%
processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration     pickup_datetime        date  day_of_week  \
# id
# id2875421           6.122493 2016-03-14 17:24:55  2016-03-14            0
# id2377394           6.498282 2016-06-12 00:43:35  2016-06-12            6
# id3858529           7.661527 2016-01-19 11:35:24  2016-01-19            1
# id3504673           6.063785 2016-04-06 19:32:31  2016-04-06            2
# id2181028           6.077642 2016-03-26 13:30:55  2016-03-26            5
#
#            hour  month  anomaly  traffic_jam
# id
# id2875421    17      3        0            0
# id2377394     0      6        0            0
# id3858529    11      1        0            1
# id3504673    19      4        0            0
# id2181028    13      3        0            0

# %% [markdown]
# Теперь колонки **pickup_datetime**, **date** можно убрать. А про оставшиеся **day_of_week**, **hour**, **month** необходимо подумать:
#
# - С одной стороны, первые две можно убрать, так как на их основе была создана колонка **traffic_jam**
# - С другой стороны, зависимость с колонкой **traffic_jam** нелинейная, поэтому можно попробовать использовать все фичи в комбинации. Конечно, лучше попробовать оба варианта и проэкспериментировать, но ради упрощения - оставим все колонки. Хоть **day_of_week**, **hour** и описываются числами, мы понимаем, что это скорее категориальные фичи. Потому что, например, отношение между 23:00 и 00:00 не такое же, как между числами 23 и 0. Закодируем их с помощью OneHotEncoder.
# - Последняя (**month**) очевидно категориальная. Можно закодировать ее тоже через OneHotEncoder.

# %%
processed_data = processed_data.drop(['pickup_datetime', 'date'], axis=1)

# %%
### Делаем OneHotEncoding и конкатим с processed_data

for col in ['day_of_week', 'hour', 'month']:
    y = pd.get_dummies(processed_data[col], prefix = col, drop_first = True)
    processed_data = pd.concat((processed_data, y), axis=1)
    processed_data = processed_data.drop(col, axis = 1)
    ### Your code is here

# %%
len(processed_data.columns)
# Out:
# 41

# %%
processed_data.head(5).to_csv('ans_3.csv', sep = ',')

# %%
processed_data.head(5)
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration  anomaly  traffic_jam  day_of_week_1  \
# id
# id2875421           6.122493        0            0              0
# id2377394           6.498282        0            0              0
# id3858529           7.661527        0            1              1
# id3504673           6.063785        0            0              0
# id2181028           6.077642        0            0              0
#
#            day_of_week_2  day_of_week_3  ...  hour_19  hour_20  hour_21  \
# id                                       ...
# id2875421              0              0  ...        0        0        0
# id2377394              0              0  ...        0        0        0
# id3858529              0              0  ...        0        0        0
# id3504673              1              0  ...        1        0        0
# id2181028              0              0  ...        0        0        0
#
#            hour_22  hour_23  month_2  month_3  month_4  month_5  month_6
# id
# id2875421        0        0        0        1        0        0        0
# id2377394        0        0        0        0        0        0        1
# id3858529        0        0        0        0        0        0        0
# id3504673        0        0        0        0        1        0        0
# id2181028        0        0        0        1        0        0        0
#
# [5 rows x 41 columns]

# %% [markdown]
# Что же, мы с Вами научились с помощью EDA визуализаций понимать важность признаков не только постфактум, но и до того, как сформировался финальный датасет - на этапе **выделения базовых фичей**.

# %% [markdown]
# Обратимся теперь к методам фильтрации - например, применим корреляционный анализ для одной пары фичей, чтобы понять, нет ли относительно этих колонок в нашем датасете избытка информации.
#
# Вспомним так же изначальные вещественные признаки - distance_km, passenger_count
#
# Посчитайте корреляцию между ними. Есть ли какие-то основания для беспокойства?

# %%
### Your code is here
round(processed_data['distance_km'].corr(processed_data['passenger_count']), 3)
# Out:
# 0.017

# %%
processed_data.head()
# Out:
#            vendor_id  passenger_count  store_and_fwd_flag  distance_km  \
# id
# id2875421          1       930.399753                   0     1.500479
# id2377394          0       930.399753                   0     1.807119
# id3858529          1       930.399753                   0     6.392080
# id3504673          1       930.399753                   0     1.487155
# id2181028          1       930.399753                   0     1.189925
#
#            log_trip_duration  anomaly  traffic_jam  day_of_week_1  \
# id
# id2875421           6.122493        0            0              0
# id2377394           6.498282        0            0              0
# id3858529           7.661527        0            1              1
# id3504673           6.063785        0            0              0
# id2181028           6.077642        0            0              0
#
#            day_of_week_2  day_of_week_3  ...  hour_19  hour_20  hour_21  \
# id                                       ...
# id2875421              0              0  ...        0        0        0
# id2377394              0              0  ...        0        0        0
# id3858529              0              0  ...        0        0        0
# id3504673              1              0  ...        1        0        0
# id2181028              0              0  ...        0        0        0
#
#            hour_22  hour_23  month_2  month_3  month_4  month_5  month_6
# id
# id2875421        0        0        0        1        0        0        0
# id2377394        0        0        0        0        0        0        1
# id3858529        0        0        0        0        0        0        0
# id3504673        0        0        0        0        1        0        0
# id2181028        0        0        0        1        0        0        0
#
# [5 rows x 41 columns]

# %%
### На данный момент у нас 41 фича
### Представим, что хочется сократить их количество до 5.
### Воспользуемся для этим каким-нибудь методом обертки
### Например, метод прямого отбора

### Your code is here
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression

x = processed_data.drop('log_trip_duration', axis = 1)
y = processed_data['log_trip_duration']

model = LinearRegression()
sfs = SequentialFeatureSelector(model, n_features_to_select = 5)
sfs.fit(x, y)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), n_features_to_select=5)

# %%
sfs.get_feature_names_out()
# Out:
# array(['distance_km', 'traffic_jam', 'day_of_week_6', 'hour_5', 'hour_6'],
#       dtype=object)

# %%
### Представим, что мы с Вами ничего не знаем про Кросс-Валидацию и отложенную выборку
### Замерьте качество линейной регрессии на данных фичах
### Сильно ли оно отличается от полученного на Кросс-Валидации в прошлом уроке в ДЗ?
model_new = LinearRegression()
model_new.fit(x[sfs.get_feature_names_out()], y)
pred = model_new.predict(x[sfs.get_feature_names_out()])

round(np.mean((pred - y)**2), 3)
# Out:
# 0.415
